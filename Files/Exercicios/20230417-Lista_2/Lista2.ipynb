# %% [markdown]
# # Classroom
#
# ## Lista de exercícios
#
# ### Descrição
#
# João Luiz de Almeida Filho
# 10 de abr.
# 100 pontos
# Data de entrega: 17 de abr., 06:00
#
# ### Tarefa
#
# Utilizando a sua linguagem favorita resolva a lista em anexo e crie testes para cada exercício usando as ferramentas estudadas por vocês. O trabalho é individual e vai valer ponto.
# Tentem fazer por vocês mesmo sem copiar ou usar o ChatGPT. Uma vez, que o bom uso das ferramentas de testes poderá impactar o futuro profissional de vocês.
#
# Experimente fazer os casos de testes antes de fazer o exercício.

# %% [markdown]
# # Lista de exercícios de Teste de software
#
# ## Testes de unidade
#
# 1. Faça um programa que então leia uma string e a imprima
# 2. Crie um programa que imprima o comprimento de uma string
# 3. Faça um programa que conte o numero de 1's que aparecem em um string
#    - Exemplo: 0011001 -> 3
# 4. Entre com um nome e imprima o nome somente se a primeira letra do nome for "a" (maiúscula ou minúscula)
# 5. Leia um vetor contendo letras de uma frase inclusive os espaços em branco. Retire os espaços em branco do vetor e depois escreva o vetor resultante
# 6. Escreva um programa que leia a idade e o primeiro nome de várias pessoas. Seu programa deve terminar quando uma idade negativa for digitada. Ao terminar, seu programa deve escrever o nome e a idade das pessoas mais jovens e mais velhas.
# 7. Faça um programa que preencha um vetor com os modelos de cinco carros (exemplos de modelos: Fusca, Gol, Vectra, etc.). Preencha outro vetor com o consumo desses carros, isto é, quantos quilômetros cada um deles faz com um litro de combustível. Calcule e mostre:
#    1. O modelo de carro mais econômico
#    2. Quantos litros de combustível cada um dos carros cadastrados consomem para percorrer uma distância de 1.000 quilômetros
# 8. Faça um programa que contenha um menu com as seguintes opções:
#    1. Ler uma string S1 (tamanho máximo 20 caracteres)
#    2. Imprimir o tamanho da string S1
#    3. Comparar a string S1 com uma nova string S2 fornecida pelo usuário e imprimir o resultado da comparação
#    4. Concatenar a string S1 com uma nova string S2 e imprimir na tela o resultado da concatenação
#    5. Imprimir a string S1 de forma reversa
#    6. Contar quantas vezes um dado caractere aparece na string S1. Esse caractere desse ser informado pelo usuário
#    7. Substituir a primeira ocorrêcia do caractere C1 da string S1 pelo caractere C2. Os caracteres C1 e C2 serão lidos pelo usuário
#    8. Verificar se uma string S2 é substring de S1. A string S2 deve ser informada pelo usuário
#    9. Retornar uma substring da string S1. Para isso o usuário deve informar a partir de qual posição deve ser criada a substring e qual é o tamanho da substring.
# 9. Faça um programa de agenda telefônica, com as classes Agenda e Contato.
# 10. Faça um programa para controle de empréstimo de livros, com as classes Emprestimo, Livro e Pessoa.
# 11. Faça uma programa para representar a árvore genealógica de uma família. Para tal, crie uma classe Pessoa que permita indicar, além de nome e idade, o pai e a mãe. Tenha em mente que pai e mãe também são do tipo Pessoa.
#
# Para as questões 9 a 11, crie uma interface texto que utilize tratamento de exceções no caso de execução de comandos inválidos

# %%
""" 1. Faça um programa que então leia uma string e a imprima """

from unittest.mock import patch # Patch será um decorator da função que quero testar
import unittest


def q1_input_str_return():
    input_value = input()
    return input_value

def q1_input_str_print():
    input_value = input()
    print(input_value)


def test_q1_return():
    """ Test Cases
        Testar se enviar parâmetros causa erro
        Testar se não há output
        Que outro teste eu poderia executar para testar uma entrada do usuário feita internamente?
        Algo que não seja string deveria dar erro?
    """

    input_values = ['test']  # simulando entrada do usuário

    def mock_input():
        return input_values.pop(0)

    # substituindo input pelo mock usando patch
    with patch('builtins.input', side_effect=mock_input):
        result = q1_input_str_return()  # chamando a função que usa input
    condition = result == 'test'
    if condition:
        print("👍")
    assert condition # verificando o resultado


def test_q1_print():
    """ Test Cases
        Testar se enviar parâmetros causa erro
        Testar se não há output
        Que outro teste eu poderia executar para testar uma entrada do usuário feita internamente?
        Algo que não seja string deveria dar erro?
    """

    input_values = ['test']  # simulando entrada do usuário

    def mock_input():
        return input_values.pop(0)

    # substituindo input pelo mock usando patch
    with patch('builtins.input', side_effect=mock_input):
        result = q1_input_str_return()  # chamando a função que usa input
    condition = result == 'test'
    if condition:
        print("👍")
    assert condition # verificando o resultado


test_q1_return()
test_q1_print()
# Out:
# 👍

# %%
""" 2. Crie um programa que imprima o comprimento de uma string """

def q2_(str_param):
    print(len(str_param))

def test_q2_():
    # Envio de tipo diferente de string: type error
    # string vazia
    # String de 1, 10, 100 e 1000 caracteres Ex.: 1000*"J"
    pass

# %%
""" 3. Faça um programa que conte o numero de 1's que aparecem em um string. Exemplo: 0011001 -> 3 """

def q3_(str_param):
    return str_param.count('1')

def test_q3_():
    """ Test cases
    input_q3_empty = '' # 0
    input_q3_zeros = 3*'0' # 0
    input_q3_pairs = 10*'01' # 10
    input_q3_elevens = 10*'11' # 22
    input_q3_mess = '01n09r19uf28yg94b18721' # 4
    input_q3_error = typeErrors
    """
    pass

# %%
""" 4. Entre com um nome e imprima o nome somente se a primeira letra do nome for "a" (maiúscula ou minúscula) """

def q4_(str_param):
    if str_param[0] in ['a', 'A']:
        print(srt_param)

def test_q4_():
    """ Test Cases
        input_q4_ = 'agda'
        input_q4_ = 'Arnaldo'
        input_q4_ = 'aristides'
        input_q4_ = 'beto'
        input_q4_ = 'casé'
        input_q4_ = 10*'A'
        input_q4_ = 10*'a'
        input_q4_ = 'b'+10*'A'
        input_q4_ = 'B'+10*'a'
        input_q4_ = typeError
        Tem como testar se a função printou algo?
    """
    pass

# %%
""" 5. Leia um vetor contendo letras de uma frase inclusive os espaços em branco. Retire os espaços em branco do vetor e depois escreva o vetor resultante """

def q5_a(arr_param):
    # values_to_remove = ['']
    # values_to_remove = [' ']
    values_to_remove = ['', ' ']
    return_value = [i for i in arr_param if i not in ['']]
    return return_value

def q5_b(str_param):
    return_value = str_param.replace(' ', '')
    return return_value

def test_q5_():
    """ Test Cases
        3*['a ','', ' b'] -> ['a ','', ' b',]
        [' a b ','', ' ', '', 'aaa bbb'] -> [' a b ', 'aaa bbb']
        [''] -> []
        ' a b ' -> 'ab'
        ' a b  aaa bbb' -> 'abaaabbb'
        ''
    """
    pass

# %%
""" 6. Escreva um programa que leia a idade e o primeiro nome de várias pessoas.
    Seu programa deve terminar quando uma idade negativa for digitada.
    Ao terminar, seu programa deve escrever o nome e a idade das pessoas mais jovens e mais velhas.
"""
import sys

def q6_():
    age = 1
    max_age = -sys.maxsize-1
    min_age = sys.maxsize
    name = ''
    min_names = []
    max_names = []
    while age >= 0:
        age = int(input('Age: '))
        
        if age < 0: break
        
        name = input('Name: ')
        first_name = name.split()[0]
        
        if age > max_age:
            max_age = age
            max_names = [first_name]
        elif age == max_age:
            max_names.append(first_name)
        
        if age < min_age:
            min_age = age
            min_names = [first_names]
        elif age == min_age:
            min_names.append(first_name)
    return_value = {min_age: min_names, max_age: max_names} if len(min_names+max_names) > 0 else {}
    return return_value

def test_q6_():
    """ Test Cases
        Tem como simular input de usuário?
            Talvez usando o Yield/geradores
        Input = [
            (50, 'Alberto'),
            (20, 'Beto'),
            (20, 'Ciro'),
            (60, 'Diana Dias'),
            (10, 'Eliana'),
            (60, 'Fábio Fernandes'),
            (-1)
        ]
        Output: {10: ['Eliana'], 60: ['Diana','Fábio']}
        Input = [
            (-1)
        ]
        Output: {}
        Input = [
            (50, 'Alberto'),
            (-1)
        ]
        Output: {50: ['Alberto']}
        erros: escrever caracteres ao invés de inteiro na idade
    """
    pass

# %%
""" 7. Faça um programa que preencha um vetor com os modelos de cinco carros (exemplos de modelos: Fusca, Gol, Vectra, etc.). Preencha outro vetor com o consumo desses carros, isto é, quantos quilômetros cada um deles faz com um litro de combustível. Calcule e mostre:
   1. O modelo de carro mais econômico
   2. Quantos litros de combustível cada um dos carros cadastrados consomem para percorrer uma distância de 1.000 quilômetros
   """

def q7_():
    def get_five_car_models(auto_mode = False):
        car_models = []
        if auto_mode:
            car_models = ['A', 'B', 'C', 'D', 'E']
        else:
            for i in range(5):
                car_models.append(input('Car model ' + str(i+1) + ': '))
        return car_models
    
    def get_five_kml(car_models, auto_mode = False):
        KM_L = []
        if auto_mode:
            KM_L = [[6, 7, 10, 9, 10]]
        else:
            for i in range(5):
                KM_L.append(input(car_models[i], ' consumption (KM/L): '))
        return KM_L
    
    def find_indices(list_to_check, item_to_find):
        return [idx for idx, value in enumerate(list_to_check) if value == item_to_find]
    
    def get_most_economic(car_models, KM_L):
        max_v = max(KM_L)
        economic_cars_indices = find_indices(car_models, max_v)
        returned_value = []
        return = returned_value
    
    def consumption_per_megameter(car_models, KM_L):
        returned_value = []
        return = returned_value
    
    car_models = get_five_car_models()
    KM_L = get_five_kml(car_models)
    most_economic = get_most_economic(car_models, KM_L)
    consumption_per_megameter = consumption_per_megameter(car_models, KM_L)
    pass

def test_q7_():
    """ Test Cases
        
        Modelos = ['A', 'B', 'C', 'D', 'E']
        KM_L = [6, 7, 8, 9, 10]
    """
    pass

# %%
class teste():
    teste1 = 1
    def __init__(self, valor):
        """ construtor """
        self.teste2 = valor
        

testea = teste('a')
testeb = teste('b')

print(testea.teste1, end=' ')
testea.teste1 += testea.teste1
print(testea.teste1)
print(testea.teste2, end=' ')
testea.teste2 += testea.teste2
print(testea.teste2)
print()
print(testeb.teste1, end=' ')
testeb.teste1 += testeb.teste1
print(testeb.teste1)
print(testeb.teste2, end=' ')
testeb.teste2 += testeb.teste2
print(testeb.teste2)

print()
print(list(range(1,10)))
# Out:
# 1 2
# a aa
#
# 1 2
# b bb
#
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
""" 8. Faça um programa que contenha um menu com as seguintes opções:
   1. Ler uma string S1 (tamanho máximo 20 caracteres)
   2. Imprimir o tamanho da string S1
   3. Comparar a string S1 com uma nova string S2 fornecida pelo usuário e imprimir o resultado da comparação
   4. Concatenar a string S1 com uma nova string S2 e imprimir na tela o resultado da concatenação
   5. Imprimir a string S1 de forma reversa
   6. Contar quantas vezes um dado caractere aparece na string S1. Esse caractere desse ser informado pelo usuário
   7. Substituir a primeira ocorrêcia do caractere C1 da string S1 pelo caractere C2. Os caracteres C1 e C2 serão lidos pelo usuário
   8. Verificar se uma string S2 é substring de S1. A string S2 deve ser informada pelo usuário
   9. Retornar uma substring da string S1. Para isso o usuário deve informar a partir de qual posição deve ser criada a substring e qual é o tamanho da substring.
"""

def q8_():
    pass

def test_q8_():
    pass

# %%
""" 9. Faça um programa de agenda telefônica, com as classes Agenda e Contato. """

def q9_():
    pass

def test_q9_():
    pass

# %%
""" 10. Faça um programa para controle de empréstimo de livros, com as classes Emprestimo, Livro e Pessoa. """

def q10_():
    pass

def test_q10_():
    pass

# %%
""" 11. Faça uma programa para representar a árvore genealógica de uma família. Para tal, crie uma classe Pessoa que permita indicar, além de nome e idade, o pai e a mãe. Tenha em mente que pai e mãe também são do tipo Pessoa. """

def q11_():
    pass

def test_q11_():
    pass

# %%
# Teste Output

def test_q1_a_input_str_print():
    """ Test Output """
    out = StringIO()
    sys.stdout = out
    
    frutas = "1234"
    print(frutas)

    output = out.getvalue().strip()
    assert output == "1234"

# %%
# Teste Input

@patch('builtins.input', return_value='42')
def test_q1_b_input_str_print(mock_input):
    """ ... """
    condition = input() == '42'
    print(condition)
    assert condition, 'error'


test_q1_b_input_str_print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       7     print(condition)
#       8     assert condition, 'error'
# ---> 11 test_q1_b_input_str_print()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\unittest\mock.py:1379, in _patch.decorate_callable.<locals>.patched(*args, **keywargs)
#    1374 @wraps(func)
#    1375 def patched(*args, **keywargs):
#    1376     with self.decoration_helper(patched,
#    1377                                 args,
#    1378                                 keywargs) as (newargs, newkeywargs):
# -> 1379         return func(*newargs, **newkeywargs)
#
# TypeError: test_q1_b_input_str_print() takes 0 positional arguments but 1 was given

# %%
print(None)
# Out:
# None
